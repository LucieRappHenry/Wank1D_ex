# %%
import numpy as np
import os,glob,struct
import xarray as xr
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
from parflow import Run
from parflow.tools.fs import exists, chdir, mkdir, cp, rm
from parflow import read_pfb, read_pfb_sequence, ParflowBinaryReader
import os,shutil,copy

# %%
root_dir = "/home/vagrant/projets/simus/"
forc_dir = "/home/vagrant/projets/forcings/soudanian/"

# %% [raw]
# The original domain definition and run setup is found in root_dir+'hillslope_sens.py' which is used to create the pfidb we will start from

# %%
hill = Run.from_definition(root_dir+'hillslope.pfidb')
# Out:
#  => Error during CLM import - CLM specific key have been skipped

# %% [markdown]
# Run Simulation #1

# %%
wdir = root_dir+'results_benchmark/'
if os.path.exists(wdir):
    shutil.rmtree(wdir)
os.mkdir(wdir)

shutil.copy(forc_dir+'lai.dat',wdir+'lai.dat')
shutil.copy(forc_dir+'sai.dat',wdir+'sai.dat')
shutil.copy(forc_dir+'z0m_last_day_filled.dat',wdir+'z0m.dat')
shutil.copy(forc_dir+'displa_last_day_filled.dat',wdir+'displa.dat')
shutil.copy(forc_dir+'forcagePF.200706070809101112131415_forc_nal2.30mn.dat',wdir+'forcagePF.txt.0')
shutil.copy(root_dir+'veg_map_trees.pfb',wdir+'veg_map.pfb')
shutil.copy(root_dir+'drv_vegm_trees.dat',wdir+'drv_vegm.dat')
shutil.copy(root_dir+'drv_vegp.dat',wdir+'drv_vegp.dat')
shutil.copy(root_dir+'drv_clmin.dat.0',wdir+'drv_clmin.dat')

hill.dist(wdir+'veg_map.pfb')

hill.run(working_directory=wdir,skip_validation=True)
# Out:
# Warning: /home/vagrant/projets/simus/results_benchmark/drv_clmin.dat will not be overwritten unless OverwriteDrvClmin is set to True. Changes to the file may not be reflected in the calculation
# Warning: /home/vagrant/projets/simus/results_benchmark/drv_vegm.dat will not be overwritten unless OverwriteDrvVegm is set to True. Changes to the file may not be reflected in the calculation
# Warning: /home/vagrant/projets/simus/results_benchmark/drv_vegp.dat will not be overwritten unless OverwriteDrvVegp is set to True. Changes to the file may not be reflected in the calculation
#
# # ==============================================================================
# # ParFlow directory
# #  - /home/vagrant/PFTree/parflow
# # ParFlow version
# #  - 3.3.1
# # Working directory
# #  - /home/vagrant/projets/simus/results_benchmark
# # ParFlow database
# #  - hillslope.pfidb
# # ==============================================================================
#
# # ==============================================================================
# # ParFlow ran successfully 💦 💦 💦
# # ==============================================================================

# %% [markdown]
# Run simulation #2

# %%
hill2 = hill.clone('hillslope2')

# %%
hill.Solver.CLM.VegWaterStress
# Out:
# 'Saturation'

# %%
hill2.Solver.CLM.VegWaterStress = None

# %%
wdir = root_dir+'results_nowaterstress/'

# %%
if os.path.exists(wdir):
    shutil.rmtree(wdir)
os.mkdir(wdir)

shutil.copy(forc_dir+'lai.dat',wdir+'lai.dat')
shutil.copy(forc_dir+'sai.dat',wdir+'sai.dat')
shutil.copy(forc_dir+'z0m_last_day_filled.dat',wdir+'z0m.dat')
shutil.copy(forc_dir+'displa_last_day_filled.dat',wdir+'displa.dat')
shutil.copy(forc_dir+'forcagePF.200706070809101112131415_forc_nal2.30mn.dat',wdir+'forcagePF.txt.0')
shutil.copy(root_dir+'veg_map_trees.pfb',wdir+'veg_map.pfb')
shutil.copy(root_dir+'drv_vegm_trees.dat',wdir+'drv_vegm.dat')
shutil.copy(root_dir+'drv_vegp.dat',wdir+'drv_vegp.dat')
shutil.copy(root_dir+'drv_clmin.dat.0',wdir+'drv_clmin.dat')

hill2.dist(wdir+'veg_map.pfb')

hill2.run(working_directory=wdir,skip_validation=True)
# Out:
# Warning: /home/hectorb/PARFLOW/PROJECTS/test_cases/hillslope/ara_bele/simus/results_nowaterstress/drv_clmin.dat will not be overwritten unless OverwriteDrvClmin is set to True. Changes to the file may not be reflected in the calculation
# Warning: /home/hectorb/PARFLOW/PROJECTS/test_cases/hillslope/ara_bele/simus/results_nowaterstress/drv_vegm.dat will not be overwritten unless OverwriteDrvVegm is set to True. Changes to the file may not be reflected in the calculation
# Warning: /home/hectorb/PARFLOW/PROJECTS/test_cases/hillslope/ara_bele/simus/results_nowaterstress/drv_vegp.dat will not be overwritten unless OverwriteDrvVegp is set to True. Changes to the file may not be reflected in the calculation
#
# # ==============================================================================
# # ParFlow directory
# #  - /home/hectorb/PARFLOW/SOURCES/PF_2022_07/parflow
# # ParFlow version
# #  - 3.3.1
# # Working directory
# #  - /home/hectorb/PARFLOW/PROJECTS/test_cases/hillslope/ara_bele/simus/results_nowaterstress
# # ParFlow database
# #  - hillslope2.pfidb
# # ==============================================================================
#
# # ==============================================================================
# # ParFlow ran successfully 💦 💦 💦
# # ==============================================================================

# %%
hill3 = hill2.clone('hillslope3')
hill3.TimingInfo.StopTime = 24

# %%
wdir = root_dir+'results_nowaterstress_temp/'

# %%
if os.path.exists(wdir):
    shutil.rmtree(wdir)
os.mkdir(wdir)

shutil.copy(forc_dir+'lai.dat',wdir+'lai.dat')
shutil.copy(forc_dir+'sai.dat',wdir+'sai.dat')
shutil.copy(forc_dir+'z0m_last_day_filled.dat',wdir+'z0m.dat')
shutil.copy(forc_dir+'displa_last_day_filled.dat',wdir+'displa.dat')
shutil.copy(forc_dir+'forcagePF.200706070809101112131415_forc_nal2.30mn.dat',wdir+'forcagePF.txt.0')
shutil.copy(root_dir+'veg_map_trees.pfb',wdir+'veg_map.pfb')
shutil.copy(root_dir+'drv_vegm_trees.dat',wdir+'drv_vegm.dat')
shutil.copy(root_dir+'drv_vegp.dat',wdir+'drv_vegp.dat')
shutil.copy(root_dir+'drv_clmin.dat.0',wdir+'drv_clmin.dat')

hill3.dist(wdir+'veg_map.pfb')

hill3.run(working_directory=wdir,skip_validation=True)
# Out:
# Warning: /home/hectorb/PARFLOW/PROJECTS/test_cases/hillslope/ara_bele/simus/results_nowaterstress_temp/drv_clmin.dat will not be overwritten unless OverwriteDrvClmin is set to True. Changes to the file may not be reflected in the calculation
# Warning: /home/hectorb/PARFLOW/PROJECTS/test_cases/hillslope/ara_bele/simus/results_nowaterstress_temp/drv_vegm.dat will not be overwritten unless OverwriteDrvVegm is set to True. Changes to the file may not be reflected in the calculation
# Warning: /home/hectorb/PARFLOW/PROJECTS/test_cases/hillslope/ara_bele/simus/results_nowaterstress_temp/drv_vegp.dat will not be overwritten unless OverwriteDrvVegp is set to True. Changes to the file may not be reflected in the calculation
#
# # ==============================================================================
# # ParFlow directory
# #  - /home/hectorb/PARFLOW/SOURCES/PF_2022_07/parflow
# # ParFlow version
# #  - 3.3.1
# # Working directory
# #  - /home/hectorb/PARFLOW/PROJECTS/test_cases/hillslope/ara_bele/simus/results_nowaterstress_temp
# # ParFlow database
# #  - hillslope3.pfidb
# # ==============================================================================
#
# # ==============================================================================
# # ParFlow ran successfully 💦 💦 💦
# # ==============================================================================

# %%
with ParflowBinaryReader(wdir+'hillslope2.out.press.00000.pfb') as s: h = s.header
print(h)
# Out:
# {'x': 0.0, 'y': 0.0, 'z': 0.0, 'nx': 1, 'ny': 50, 'nz': 24, 'dx': 10.0, 'dy': 10.0, 'dz': 1.0, 'n_subgrids': 2, 'p': 1, 'q': 2, 'r': 1}

# %%
ds = xr.open_dataset(wdir+'hillslope2.out.press.00000.pfb',name="press",engine='parflow')

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (z: 24, y: 50)
# Dimensions without coordinates: z, y
# Data variables:
#     press    (z, y) float64 ...

# %%
ds3 = xr.open_dataset(wdir+'hillslope3.out.pfmetadata',name="press",engine='parflow')

# %%
ds3
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/lib/python3.9/site-packages/IPython/core/formatters.py:343, in BaseFormatter.__call__(self, obj)
#     341     method = get_real_method(obj, self.print_method)
#     342     if method is not None:
# --> 343         return method()
#     344     return None
#     345 else:
#
# File ~/miniconda3/lib/python3.9/site-packages/xarray/core/dataset.py:2082, in Dataset._repr_html_(self)
#    2080 if OPTIONS["display_style"] == "text":
#    2081     return f"<pre>{escape(repr(self))}</pre>"
# -> 2082 return formatting_html.dataset_repr(self)
#
# File ~/miniconda3/lib/python3.9/site-packages/xarray/core/formatting_html.py:282, in dataset_repr(ds)
#     275 obj_type = f"xarray.{type(ds).__name__}"
#     277 header_components = [f"<div class='xr-obj-type'>{escape(obj_type)}</div>"]
#     279 sections = [
#     280     dim_section(ds),
#     281     coord_section(ds.coords),
# --> 282     datavar_section(ds.data_vars),
#     283     attr_section(ds.attrs),
#     284 ]
#     286 return _obj_repr(ds, header_components, sections)
#
# File ~/miniconda3/lib/python3.9/site-packages/xarray/core/formatting_html.py:161, in _mapping_section(mapping, name, details_func, max_items_collapse, expand_option_name, enabled)
#     154 expanded = _get_boolean_with_default(
#     155     expand_option_name, n_items < max_items_collapse
#     156 )
#     157 collapsed = not expanded
#     159 return collapsible_section(
#     160     name,
# --> 161     details=details_func(mapping),
#     162     n_items=n_items,
#     163     enabled=enabled,
#     164     collapsed=collapsed,
#     165 )
#
# File ~/miniconda3/lib/python3.9/site-packages/xarray/core/formatting_html.py:120, in summarize_vars(variables)
#     119 def summarize_vars(variables):
# --> 120     vars_li = "".join(
#     121         f"<li class='xr-var-item'>{summarize_variable(k, v)}</li>"
#     122         for k, v in variables.items()
#     123     )
#     125     return f"<ul class='xr-var-list'>{vars_li}</ul>"
#
# File ~/miniconda3/lib/python3.9/site-packages/xarray/core/formatting_html.py:121, in <genexpr>(.0)
#     119 def summarize_vars(variables):
#     120     vars_li = "".join(
# --> 121         f"<li class='xr-var-item'>{summarize_variable(k, v)}</li>"
#     122         for k, v in variables.items()
#     123     )
#     125     return f"<ul class='xr-var-list'>{vars_li}</ul>"
#
# File ~/miniconda3/lib/python3.9/site-packages/xarray/core/formatting_html.py:86, in summarize_variable(name, var, is_index, dtype)
#      84 preview = escape(inline_variable_array_repr(variable, 35))
#      85 attrs_ul = summarize_attrs(var.attrs)
# ---> 86 data_repr = short_data_repr_html(variable)
#      88 attrs_icon = _icon("icon-file-text2")
#      89 data_icon = _icon("icon-database")
#
# File ~/miniconda3/lib/python3.9/site-packages/xarray/core/formatting_html.py:32, in short_data_repr_html(array)
#      30 if hasattr(internal_data, "_repr_html_"):
#      31     return internal_data._repr_html_()
# ---> 32 text = escape(short_data_repr(array))
#      33 return f"<pre>{text}</pre>"
#
# File ~/miniconda3/lib/python3.9/site-packages/xarray/core/formatting.py:548, in short_data_repr(array)
#     546     return limit_lines(repr(array.data), limit=40)
#     547 elif array._in_memory or array.size < 1e5:
# --> 548     return short_numpy_repr(array)
#     549 else:
#     550     # internal xarray array type
#     551     return f"[{array.size} values with dtype={array.dtype}]"
#
# File ~/miniconda3/lib/python3.9/site-packages/xarray/core/formatting.py:520, in short_numpy_repr(array)
#     519 def short_numpy_repr(array):
# --> 520     array = np.asarray(array)
#     522     # default to lower precision so a full (abbreviated) line can fit on
#     523     # one line with the default display_width
#     524     options = {
#     525         "precision": 6,
#     526         "linewidth": OPTIONS["display_width"],
#     527         "threshold": OPTIONS["display_values_threshold"],
#     528     }
#
# File ~/miniconda3/lib/python3.9/site-packages/xarray/core/common.py:156, in AbstractArray.__array__(self, dtype)
#     155 def __array__(self: Any, dtype: DTypeLike = None) -> np.ndarray:
# --> 156     return np.asarray(self.values, dtype=dtype)
#
# File ~/miniconda3/lib/python3.9/site-packages/xarray/core/variable.py:527, in Variable.values(self)
#     524 @property
#     525 def values(self):
#     526     """The variable's data as a numpy.ndarray"""
# --> 527     return _as_array_or_item(self._data)
#
# File ~/miniconda3/lib/python3.9/site-packages/xarray/core/variable.py:267, in _as_array_or_item(data)
#     253 def _as_array_or_item(data):
#     254     """Return the given values as a numpy array, or as an individual item if
#     255     it's a 0d datetime64 or timedelta64 array.
#     256
#    (...)
#     265     TODO: remove this (replace with np.asarray) once these issues are fixed
#     266     """
# --> 267     data = np.asarray(data)
#     268     if data.ndim == 0:
#     269         if data.dtype.kind == "M":
#
# File ~/miniconda3/lib/python3.9/site-packages/xarray/core/indexing.py:653, in MemoryCachedArray.__array__(self, dtype)
#     652 def __array__(self, dtype=None):
# --> 653     self._ensure_cached()
#     654     return np.asarray(self.array, dtype=dtype)
#
# File ~/miniconda3/lib/python3.9/site-packages/xarray/core/indexing.py:650, in MemoryCachedArray._ensure_cached(self)
#     648 def _ensure_cached(self):
#     649     if not isinstance(self.array, NumpyIndexingAdapter):
# --> 650         self.array = NumpyIndexingAdapter(np.asarray(self.array))
#
# File ~/miniconda3/lib/python3.9/site-packages/xarray/core/indexing.py:623, in CopyOnWriteArray.__array__(self, dtype)
#     622 def __array__(self, dtype=None):
# --> 623     return np.asarray(self.array, dtype=dtype)
#
# File ~/miniconda3/lib/python3.9/site-packages/xarray/core/indexing.py:524, in LazilyIndexedArray.__array__(self, dtype)
#     522 def __array__(self, dtype=None):
#     523     array = as_indexable(self.array)
# --> 524     return np.asarray(array[self.key], dtype=None)
#
# File ~/miniconda3/lib/python3.9/site-packages/parflow/tools/pf_backend.py:572, in ParflowBackendArray.__getitem__(self, key)
#     568 def __getitem__(
#     569         self, key: xr.core.indexing.ExplicitIndexer
#     570 ) -> np.ndarray:
#     571     """Dunder method to call implement the underlying indexing scheme"""
# --> 572     return indexing.explicit_indexing_adapter(
#     573         key,
#     574         self.shape,
#     575         indexing.IndexingSupport.OUTER,
#     576         self._getitem,
#     577     )
#
# File ~/miniconda3/lib/python3.9/site-packages/xarray/core/indexing.py:818, in explicit_indexing_adapter(key, shape, indexing_support, raw_indexing_method)
#     815 result = raw_indexing_method(raw_key.tuple)
#     816 if numpy_indices.tuple:
#     817     # index the loaded np.ndarray
# --> 818     result = NumpyIndexingAdapter(np.asarray(result))[numpy_indices]
#     819 return result
#
# File ~/miniconda3/lib/python3.9/site-packages/dask/array/core.py:1694, in Array.__array__(self, dtype, **kwargs)
#    1693 def __array__(self, dtype=None, **kwargs):
# -> 1694     x = self.compute()
#    1695     if dtype and x.dtype != dtype:
#    1696         x = x.astype(dtype)
#
# File ~/miniconda3/lib/python3.9/site-packages/dask/base.py:315, in DaskMethodsMixin.compute(self, **kwargs)
#     291 def compute(self, **kwargs):
#     292     """Compute this dask collection
#     293
#     294     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     313     dask.base.compute
#     314     """
# --> 315     (result,) = compute(self, traverse=False, **kwargs)
#     316     return result
#
# File ~/miniconda3/lib/python3.9/site-packages/dask/base.py:600, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     597     keys.append(x.__dask_keys__())
#     598     postcomputes.append(x.__dask_postcompute__())
# --> 600 results = schedule(dsk, keys, **kwargs)
#     601 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/miniconda3/lib/python3.9/site-packages/dask/threaded.py:89, in get(dsk, keys, cache, num_workers, pool, **kwargs)
#      86     elif isinstance(pool, multiprocessing.pool.Pool):
#      87         pool = MultiprocessingPoolExecutor(pool)
# ---> 89 results = get_async(
#      90     pool.submit,
#      91     pool._max_workers,
#      92     dsk,
#      93     keys,
#      94     cache=cache,
#      95     get_id=_thread_get_id,
#      96     pack_exception=pack_exception,
#      97     **kwargs,
#      98 )
#     100 # Cleanup pools associated to dead threads
#     101 with pools_lock:
#
# File ~/miniconda3/lib/python3.9/site-packages/dask/local.py:511, in get_async(submit, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, chunksize, **kwargs)
#     509         _execute_task(task, data)  # Re-execute locally
#     510     else:
# --> 511         raise_exception(exc, tb)
#     512 res, worker_id = loads(res_info)
#     513 state["cache"][key] = res
#
# File ~/miniconda3/lib/python3.9/site-packages/dask/local.py:319, in reraise(exc, tb)
#     317 if exc.__traceback__ is not tb:
#     318     raise exc.with_traceback(tb)
# --> 319 raise exc
#
# File ~/miniconda3/lib/python3.9/site-packages/dask/local.py:224, in execute_task(key, task_info, dumps, loads, get_id, pack_exception)
#     222 try:
#     223     task, data = loads(task_info)
# --> 224     result = _execute_task(task, data)
#     225     id = get_id()
#     226     result = dumps((result, id))
#
# File ~/miniconda3/lib/python3.9/site-packages/dask/core.py:119, in _execute_task(arg, cache, dsk)
#     115     func, args = arg[0], arg[1:]
#     116     # Note: Don't assign the subtask results to a variable. numpy detects
#     117     # temporaries by their reference count and can execute certain
#     118     # operations in-place.
# --> 119     return func(*(_execute_task(a, cache) for a in args))
#     120 elif not ishashable(arg):
#     121     return arg
#
# File ~/miniconda3/lib/python3.9/site-packages/parflow/tools/pf_backend.py:504, in _getitem_no_state(file_or_seq, key, dims, mode, z_first, z_is)
#     502 accessor['time']['indices'] = slice(None, None, None)
#     503 # Read the array
# --> 504 sub = read_pfb_sequence(
#     505     read_files,
#     506     keys=accessor,
#     507     z_first=z_first,
#     508     z_is=z_is,
#     509 )
#     510 # Select out specific indices from from the array
#     511 sub = sub[tuple([accessor[d]['indices'] for d in dims])]
#
# File ~/miniconda3/lib/python3.9/site-packages/parflow/tools/io.py:260, in read_pfb_sequence(file_seq, keys, z_first, z_is)
#     258     nx, ny, nz = base_header['nx'], base_header['ny'], base_header['nz']
#     259 else:
# --> 260     start_x = keys['x']['start'] or 0
#     261     start_y = keys['y']['start'] or 0
#     262     start_z = keys[z_is]['start'] or 0
#
# KeyError: 'x'
# <xarray.Dataset>
# Dimensions:           (time: 24, z: 24, y: 50)
# Dimensions without coordinates: time, z, y
# Data variables:
#     pressure          (time, z, y) float64 ...
#     saturation        (time, z, y) float64 ...
#     permeability_x    (z, y) float64 ...
#     permeability_y    (z, y) float64 ...
#     permeability_z    (z, y) float64 ...
#     porosity          (z, y) float64 ...
#     specific storage  (z, y) float64 ...
#     slope_x           (y) float64 ...
#     slope_y           (y) float64 ...
#     mannings          (y) float64 ...
#     dz multiplier     (z, y) float64 ...
#     mask              (z, y) float64 ...
# Attributes:
#     pf_metadata_file:  /home/hectorb/PARFLOW/PROJECTS/test_cases/hillslope/ar...
#     parflow_version:   v3.3.1-IGE-192-g7bea64e

# %%
ds2 = xr.open_dataset(wdir+'hillslope2.out.pfmetadata',name="press",engine='parflow')

# %%
ds2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/miniconda3/lib/python3.9/site-packages/IPython/core/formatters.py:343, in BaseFormatter.__call__(self, obj)
#     341     method = get_real_method(obj, self.print_method)
#     342     if method is not None:
# --> 343         return method()
#     344     return None
#     345 else:
#
# File ~/miniconda3/lib/python3.9/site-packages/xarray/core/dataset.py:2082, in Dataset._repr_html_(self)
#    2080 if OPTIONS["display_style"] == "text":
#    2081     return f"<pre>{escape(repr(self))}</pre>"
# -> 2082 return formatting_html.dataset_repr(self)
#
# File ~/miniconda3/lib/python3.9/site-packages/xarray/core/formatting_html.py:282, in dataset_repr(ds)
#     275 obj_type = f"xarray.{type(ds).__name__}"
#     277 header_components = [f"<div class='xr-obj-type'>{escape(obj_type)}</div>"]
#     279 sections = [
#     280     dim_section(ds),
#     281     coord_section(ds.coords),
# --> 282     datavar_section(ds.data_vars),
#     283     attr_section(ds.attrs),
#     284 ]
#     286 return _obj_repr(ds, header_components, sections)
#
# File ~/miniconda3/lib/python3.9/site-packages/xarray/core/formatting_html.py:161, in _mapping_section(mapping, name, details_func, max_items_collapse, expand_option_name, enabled)
#     154 expanded = _get_boolean_with_default(
#     155     expand_option_name, n_items < max_items_collapse
#     156 )
#     157 collapsed = not expanded
#     159 return collapsible_section(
#     160     name,
# --> 161     details=details_func(mapping),
#     162     n_items=n_items,
#     163     enabled=enabled,
#     164     collapsed=collapsed,
#     165 )
#
# File ~/miniconda3/lib/python3.9/site-packages/xarray/core/formatting_html.py:120, in summarize_vars(variables)
#     119 def summarize_vars(variables):
# --> 120     vars_li = "".join(
#     121         f"<li class='xr-var-item'>{summarize_variable(k, v)}</li>"
#     122         for k, v in variables.items()
#     123     )
#     125     return f"<ul class='xr-var-list'>{vars_li}</ul>"
#
# File ~/miniconda3/lib/python3.9/site-packages/xarray/core/formatting_html.py:121, in <genexpr>(.0)
#     119 def summarize_vars(variables):
#     120     vars_li = "".join(
# --> 121         f"<li class='xr-var-item'>{summarize_variable(k, v)}</li>"
#     122         for k, v in variables.items()
#     123     )
#     125     return f"<ul class='xr-var-list'>{vars_li}</ul>"
#
# File ~/miniconda3/lib/python3.9/site-packages/xarray/core/formatting_html.py:86, in summarize_variable(name, var, is_index, dtype)
#      84 preview = escape(inline_variable_array_repr(variable, 35))
#      85 attrs_ul = summarize_attrs(var.attrs)
# ---> 86 data_repr = short_data_repr_html(variable)
#      88 attrs_icon = _icon("icon-file-text2")
#      89 data_icon = _icon("icon-database")
#
# File ~/miniconda3/lib/python3.9/site-packages/xarray/core/formatting_html.py:32, in short_data_repr_html(array)
#      30 if hasattr(internal_data, "_repr_html_"):
#      31     return internal_data._repr_html_()
# ---> 32 text = escape(short_data_repr(array))
#      33 return f"<pre>{text}</pre>"
#
# File ~/miniconda3/lib/python3.9/site-packages/xarray/core/formatting.py:548, in short_data_repr(array)
#     546     return limit_lines(repr(array.data), limit=40)
#     547 elif array._in_memory or array.size < 1e5:
# --> 548     return short_numpy_repr(array)
#     549 else:
#     550     # internal xarray array type
#     551     return f"[{array.size} values with dtype={array.dtype}]"
#
# File ~/miniconda3/lib/python3.9/site-packages/xarray/core/formatting.py:520, in short_numpy_repr(array)
#     519 def short_numpy_repr(array):
# --> 520     array = np.asarray(array)
#     522     # default to lower precision so a full (abbreviated) line can fit on
#     523     # one line with the default display_width
#     524     options = {
#     525         "precision": 6,
#     526         "linewidth": OPTIONS["display_width"],
#     527         "threshold": OPTIONS["display_values_threshold"],
#     528     }
#
# File ~/miniconda3/lib/python3.9/site-packages/xarray/core/common.py:156, in AbstractArray.__array__(self, dtype)
#     155 def __array__(self: Any, dtype: DTypeLike = None) -> np.ndarray:
# --> 156     return np.asarray(self.values, dtype=dtype)
#
# File ~/miniconda3/lib/python3.9/site-packages/xarray/core/variable.py:527, in Variable.values(self)
#     524 @property
#     525 def values(self):
#     526     """The variable's data as a numpy.ndarray"""
# --> 527     return _as_array_or_item(self._data)
#
# File ~/miniconda3/lib/python3.9/site-packages/xarray/core/variable.py:267, in _as_array_or_item(data)
#     253 def _as_array_or_item(data):
#     254     """Return the given values as a numpy array, or as an individual item if
#     255     it's a 0d datetime64 or timedelta64 array.
#     256
#    (...)
#     265     TODO: remove this (replace with np.asarray) once these issues are fixed
#     266     """
# --> 267     data = np.asarray(data)
#     268     if data.ndim == 0:
#     269         if data.dtype.kind == "M":
#
# File ~/miniconda3/lib/python3.9/site-packages/xarray/core/indexing.py:653, in MemoryCachedArray.__array__(self, dtype)
#     652 def __array__(self, dtype=None):
# --> 653     self._ensure_cached()
#     654     return np.asarray(self.array, dtype=dtype)
#
# File ~/miniconda3/lib/python3.9/site-packages/xarray/core/indexing.py:650, in MemoryCachedArray._ensure_cached(self)
#     648 def _ensure_cached(self):
#     649     if not isinstance(self.array, NumpyIndexingAdapter):
# --> 650         self.array = NumpyIndexingAdapter(np.asarray(self.array))
#
# File ~/miniconda3/lib/python3.9/site-packages/xarray/core/indexing.py:623, in CopyOnWriteArray.__array__(self, dtype)
#     622 def __array__(self, dtype=None):
# --> 623     return np.asarray(self.array, dtype=dtype)
#
# File ~/miniconda3/lib/python3.9/site-packages/xarray/core/indexing.py:524, in LazilyIndexedArray.__array__(self, dtype)
#     522 def __array__(self, dtype=None):
#     523     array = as_indexable(self.array)
# --> 524     return np.asarray(array[self.key], dtype=None)
#
# File ~/miniconda3/lib/python3.9/site-packages/parflow/tools/pf_backend.py:572, in ParflowBackendArray.__getitem__(self, key)
#     568 def __getitem__(
#     569         self, key: xr.core.indexing.ExplicitIndexer
#     570 ) -> np.ndarray:
#     571     """Dunder method to call implement the underlying indexing scheme"""
# --> 572     return indexing.explicit_indexing_adapter(
#     573         key,
#     574         self.shape,
#     575         indexing.IndexingSupport.OUTER,
#     576         self._getitem,
#     577     )
#
# File ~/miniconda3/lib/python3.9/site-packages/xarray/core/indexing.py:818, in explicit_indexing_adapter(key, shape, indexing_support, raw_indexing_method)
#     815 result = raw_indexing_method(raw_key.tuple)
#     816 if numpy_indices.tuple:
#     817     # index the loaded np.ndarray
# --> 818     result = NumpyIndexingAdapter(np.asarray(result))[numpy_indices]
#     819 return result
#
# File ~/miniconda3/lib/python3.9/site-packages/dask/array/core.py:1694, in Array.__array__(self, dtype, **kwargs)
#    1693 def __array__(self, dtype=None, **kwargs):
# -> 1694     x = self.compute()
#    1695     if dtype and x.dtype != dtype:
#    1696         x = x.astype(dtype)
#
# File ~/miniconda3/lib/python3.9/site-packages/dask/base.py:315, in DaskMethodsMixin.compute(self, **kwargs)
#     291 def compute(self, **kwargs):
#     292     """Compute this dask collection
#     293
#     294     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     313     dask.base.compute
#     314     """
# --> 315     (result,) = compute(self, traverse=False, **kwargs)
#     316     return result
#
# File ~/miniconda3/lib/python3.9/site-packages/dask/base.py:600, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     597     keys.append(x.__dask_keys__())
#     598     postcomputes.append(x.__dask_postcompute__())
# --> 600 results = schedule(dsk, keys, **kwargs)
#     601 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/miniconda3/lib/python3.9/site-packages/dask/threaded.py:89, in get(dsk, keys, cache, num_workers, pool, **kwargs)
#      86     elif isinstance(pool, multiprocessing.pool.Pool):
#      87         pool = MultiprocessingPoolExecutor(pool)
# ---> 89 results = get_async(
#      90     pool.submit,
#      91     pool._max_workers,
#      92     dsk,
#      93     keys,
#      94     cache=cache,
#      95     get_id=_thread_get_id,
#      96     pack_exception=pack_exception,
#      97     **kwargs,
#      98 )
#     100 # Cleanup pools associated to dead threads
#     101 with pools_lock:
#
# File ~/miniconda3/lib/python3.9/site-packages/dask/local.py:511, in get_async(submit, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, chunksize, **kwargs)
#     509         _execute_task(task, data)  # Re-execute locally
#     510     else:
# --> 511         raise_exception(exc, tb)
#     512 res, worker_id = loads(res_info)
#     513 state["cache"][key] = res
#
# File ~/miniconda3/lib/python3.9/site-packages/dask/local.py:319, in reraise(exc, tb)
#     317 if exc.__traceback__ is not tb:
#     318     raise exc.with_traceback(tb)
# --> 319 raise exc
#
# File ~/miniconda3/lib/python3.9/site-packages/dask/local.py:224, in execute_task(key, task_info, dumps, loads, get_id, pack_exception)
#     222 try:
#     223     task, data = loads(task_info)
# --> 224     result = _execute_task(task, data)
#     225     id = get_id()
#     226     result = dumps((result, id))
#
# File ~/miniconda3/lib/python3.9/site-packages/dask/core.py:119, in _execute_task(arg, cache, dsk)
#     115     func, args = arg[0], arg[1:]
#     116     # Note: Don't assign the subtask results to a variable. numpy detects
#     117     # temporaries by their reference count and can execute certain
#     118     # operations in-place.
# --> 119     return func(*(_execute_task(a, cache) for a in args))
#     120 elif not ishashable(arg):
#     121     return arg
#
# File ~/miniconda3/lib/python3.9/site-packages/parflow/tools/pf_backend.py:468, in _getitem_no_state(file_or_seq, key, dims, mode, z_first, z_is)
#     463         d = ['x', 'y', 'z']
#     465     with ParflowBinaryReader(file_or_seq) as pfd:
#     466         sub = pfd.read_subarray(
#     467             start_x=int(accessor['x']['start']),
# --> 468             start_y=int(accessor['y']['start']),
#     469             start_z=int(accessor['z']['start']),
#     470             nx=int(accessor['x']['stop']),
#     471             ny=int(accessor['y']['stop']),
#     472             nz=int(accessor['z']['stop']),
#     473             z_first=z_first
#     474         )
#     475     sub = sub[accessor[d[0]]['indices'],
#     476               accessor[d[1]]['indices'],
#     477               accessor[d[2]]['indices']].squeeze()
#     478 elif mode == 'sequence':
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# <xarray.Dataset>
# Dimensions:           (time: 17520, z: 24, y: 50)
# Dimensions without coordinates: time, z, y
# Data variables:
#     pressure          (time, z, y) float64 ...
#     saturation        (time, z, y) float64 ...
#     permeability_x    (z, y) float64 ...
#     permeability_y    (z, y) float64 ...
#     permeability_z    (z, y) float64 ...
#     porosity          (z, y) float64 ...
#     specific storage  (z, y) float64 ...
#     slope_x           (y) float64 ...
#     slope_y           (y) float64 ...
#     mannings          (y) float64 ...
#     dz multiplier     (z, y) float64 ...
#     mask              (z, y) float64 ...
# Attributes:
#     pf_metadata_file:  /home/hectorb/PARFLOW/PROJECTS/test_cases/hillslope/ar...
#     parflow_version:   v3.3.1-IGE-192-g7bea64e

# %%
dslopex = xr.open_dataset(wdir+'hillslope2.out.slope_x.pfb',name="slopex",engine='parflow')

# %%
dslopex
# Out:
# <xarray.Dataset>
# Dimensions:  (y: 50)
# Dimensions without coordinates: y
# Data variables:
#     slopex   (y) float64 ...

# %%
var_dz = read_pfb(glob.glob(wdir+'*mult*.pfb')[0])[:,0,0]
var_dz = var_dz[::-1]
print(var_dz)
dz = var_dz * h['dz']
print(dz)
z = np.cumsum(dz) - var_dz/2 
print(z)
# Out:
# [0.01  0.01  0.01  0.01  0.092 0.092 0.092 0.092 0.092 0.16  0.16  0.16
#  0.16  0.16  0.24  0.24  0.24  0.24  0.24  4.3   4.3   4.3   4.3   4.3  ]
# [0.01  0.01  0.01  0.01  0.092 0.092 0.092 0.092 0.092 0.16  0.16  0.16
#  0.16  0.16  0.24  0.24  0.24  0.24  0.24  4.3   4.3   4.3   4.3   4.3  ]
# [5.000e-03 1.500e-02 2.500e-02 3.500e-02 8.600e-02 1.780e-01 2.700e-01
#  3.620e-01 4.540e-01 5.800e-01 7.400e-01 9.000e-01 1.060e+00 1.220e+00
#  1.420e+00 1.660e+00 1.900e+00 2.140e+00 2.380e+00 4.650e+00 8.950e+00
#  1.325e+01 1.755e+01 2.185e+01]

# %% [markdown]
# Read in pressure

# %%
files = np.sort(glob.glob(wdir+'*.press.*.pfb'))
da = read_pfb_sequence(files)

# %%
np.shape(da)
# Out:
# (731, 24, 50, 1)

# %%
press = xr.Dataset({"press": (("time","z","y"), da[:,:,:,0])},
    coords={"y":np.arange(start = h['y'],stop = h['y']+h['ny']*h['dy'],step=h['dy']),
        "z":-z, 
        "time": pd.date_range("2005-01-01", periods=len(files)),
        "reference_time": pd.Timestamp("2005-01-01")})

ds.press.attrs['units']='m'
ds.y.attrs['units']='meters'
ds.z.attrs['units']='meters'

# %%
def read_pf_outputs(wdir,date_start="2005-01-01"):
    # read header
    with ParflowBinaryReader(glob.glob(wdir+'*.press.00000.pfb')[0]) as s: h = s.header
    print(h)
    
    # get z
    var_dz = read_pfb(glob.glob(wdir+'*mult*.pfb')[0])[:,0,0]
    var_dz = var_dz[::-1]
    dz = var_dz * h['dz']
    z = np.cumsum(dz) - var_dz/2 
    
    # get pressure (pop(0) skips initial condition)
    files = np.sort(glob.glob(wdir+'*.press.*.pfb'))[1::]
    press = read_pfb_sequence(files)
    
    # get saturation
    files = np.sort(glob.glob(wdir+'*.satur.*.pfb'))[1::]
    satur = read_pfb_sequence(files)
    
    # get evaptranssum
    files = np.sort(glob.glob(wdir+'*.evaptranssum.*.pfb'))
    evaptranssum = read_pfb_sequence(files)
        
    # create dataset
    ds = xr.Dataset({"press": (("time","z","y"), press[:,::-1,:,0]),
                    "satur": (("time","z","y"), satur[:,::-1,:,0]),
                    "evaptranssum": (("time","z","y"), evaptranssum[:,::-1,:,0])},
        coords={"y":np.arange(start = h['y'],stop = h['y']+h['ny']*h['dy'],step=h['dy']),
            "z":-z, 
            "time": pd.date_range(date_start, periods=len(files)),
            "reference_time": pd.Timestamp(date_start)})

    # add WTD:
    ds = ds.assign(WTD = z[-1] - ds.press.isel(z=-1))
    
    ds.press.attrs['units']='m'
    ds.satur.attrs['units']='m3/m3'
    ds.evaptranssum.attrs['units']='m3/hr'
    ds.y.attrs['units']='meters'
    ds.z.attrs['units']='meters'
    return ds

# %%
ds1 = read_pf_outputs(root_dir+'results_benchmark/')
ds2 = read_pf_outputs(root_dir+'results_nowaterstress/')
# Out:
# {'x': 0.0, 'y': 0.0, 'z': 0.0, 'nx': 1, 'ny': 50, 'nz': 24, 'dx': 10.0, 'dy': 10.0, 'dz': 1.0, 'n_subgrids': 2, 'p': 1, 'q': 2, 'r': 1}
# {'x': 0.0, 'y': 0.0, 'z': 0.0, 'nx': 1, 'ny': 50, 'nz': 24, 'dx': 10.0, 'dy': 10.0, 'dz': 1.0, 'n_subgrids': 2, 'p': 1, 'q': 2, 'r': 1}

# %%
ds1.satur.sel(z=-.2,y=100,method='nearest').plot()
ds2.satur.sel(z=-.2,y=100,method='nearest').plot()

# %%
from matplotlib import pyplot as plt
ds1.WTD.isel(y=0).plot(label='ref: hill bottom')
ds1.WTD.isel(y=49).plot(label='ref: hill top')
ds2.WTD.isel(y=0).plot(label='new: hill bottom')
ds2.WTD.isel(y=49).plot(label='new: hill top')
plt.gca().legend()
plt.gca().invert_yaxis()

# %% [markdown]
# ## Lecture des variables CLM (evapotranspiration, notamment)
# Dans le manuel, les variables CLM écrites sont :
# - *eflx_lh_tot* for latent heat flux total [W/m 2 ]
# - *eflx_lwrad_out* for outgoing long-wave radiation [W/m 2 ]
# - *eflx_sh_tot* for sensible heat flux total [W/m 2 ]
# - *eflx_soil_grnd* for ground heat flux [W/m 2 ]
# - *qflx_evap_tot* for total evaporation [mm/s]
# - *qflx_evap_grnd* for ground evaporation without condensation [mm/s]
# - *qflx_evap_soi* for soil evaporation [mm/s]
# - *qflx_evap_veg* for vegetation evaporation [mm/s]
# - *qflx_tran_veg* for vegetation transpiration [mm/s]
# - *qflx_infl* for soil infiltration [mm/s]
# - *swe_out* for snow water equivalent [mm]
# - *t_grnd* for ground surface temperature [K]
# - *t_soil* for soil temperature over all layers [K]

# %%
def read_clm_outputs(wdir,date_start="2005-01-01"):
    files = np.sort(glob.glob(wdir+'*.clm_output.*.pfb'))
    clms = read_pfb_sequence(files)
    # create dataset
    ds = xr.Dataset({"lh_tot": (("time","y"), clms[:,0,:,0]),
                    "lwrad_out": (("time","y"), clms[:,1,:,0]),
                    "sh_tot": (("time","y"), clms[:,2,:,0]),
                    "soil_grnd": (("time","y"), clms[:,3,:,0]),
                    "evap_tot": (("time","y"), clms[:,4,:,0]*60*60),
                    "evap_grnd": (("time","y"), clms[:,5,:,0]*60*60),
                    "evap_soi": (("time","y"), clms[:,6,:,0]*60*60),
                    "evap_veg": (("time","y"), clms[:,7,:,0]*60*60),
                    "tran_veg": (("time","y"), clms[:,8,:,0]*60*60),
                    "infl": (("time","y"), clms[:,9,:,0]*60*60),
                    "swe_out": (("time","y"), clms[:,10,:,0]),
                    "t_grnd": (("time","y"), clms[:,11,:,0]),
                    "htop": (("time","y"), clms[:,12,:,0])},

        coords={"y":np.arange(start = h['y'],stop = h['y']+h['ny']*h['dy'],step=h['dy']),
            "time": pd.date_range(date_start, periods=len(files),freq='1H'),
            "reference_time": pd.Timestamp(date_start)})

    ds.lh_tot.attrs['units']='$W/m^2$'
    ds.lwrad_out.attrs['units']='$W/m^2$'
    ds.sh_tot.attrs['units']='$W/m^2$'
    ds.soil_grnd.attrs['units']='$W/m^2$'
    ds.evap_tot.attrs['units']='mm/h'
    ds.evap_grnd.attrs['units']='mm/h'
    ds.evap_soi.attrs['units']='mm/h'
    ds.evap_veg.attrs['units']='mm/h'
    ds.tran_veg.attrs['units']='mm/h'
    ds.infl.attrs['units']='mm/h'
    ds.swe_out.attrs['units']='mm'
    ds.t_grnd.attrs['units']='K'
    ds.htop.attrs['units']='m'

    ds.y.attrs['units']='meters'
    return ds

# %%
dc1 = read_clm_outputs(root_dir+'results_benchmark/')
dc2 = read_clm_outputs(root_dir+'results_nowaterstress/')

# %%
from matplotlib import pyplot as plt
dc1.evap_tot.isel(y=0).resample(time='D').sum().plot(label='ref: hill bottom')
dc1.evap_tot.isel(y=49).resample(time='D').sum().plot(label='ref: hill top')
dc2.evap_tot.isel(y=0).resample(time='D').sum().plot(label='new: hill bottom')
dc2.evap_tot.isel(y=49).resample(time='D').sum().plot(label='new: hill top')
plt.gca().legend()

# %%
fig, ax = plt.subplots(figsize=(12,5))
dc1.evap_tot.mean(dim='y').resample(time='D').sum().groupby('time.dayofyear').mean().plot(label='ref: evap_tot')
dc2.evap_tot.mean(dim='y').resample(time='D').sum().groupby('time.dayofyear').mean().plot(label='new: evap_tot')
a = plt.gca()
a.legend()
